# %%
import pandas as pd

df = pd.read_csv('./all_flights_with_lon_and_lat.csv')

mean_arrival_delay = df.groupby(['AIRLINE', 'MONTH'])['ARRIVAL_DELAY'].mean()
mean_arrival_delay = mean_arrival_delay.reset_index()

mean_arrival_delay.head(100)
# Out:
# /var/folders/w9/cp9skk3x10v4chw5nn5b5dxr0000gn/T/ipykernel_52177/1308691564.py:3: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./all_flights_with_lon_and_lat.csv')
#    AIRLINE  MONTH  ARRIVAL_DELAY
# 0       AA      1       6.955843
# 1       AA      2       7.530204
# 2       AA      3       6.693587
# 3       AA      4       4.931778
# 4       AA      5       5.173878
# ..     ...    ...            ...
# 95      MQ     12       0.662486
# 96      NK      1      11.398054
# 97      NK      2      16.474466
# 98      NK      3      10.039118
# 99      NK      4       8.766224
#
# [100 rows x 3 columns]

# %%
mean_arrival_delay.shape
mean_arrival_delay.to_csv('./mean_arrival_delay.csv', index=False)
